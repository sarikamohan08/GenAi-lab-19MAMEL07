# %%
# %%capture
# !pip install -q torch==1.13.1+cu116 torchvision==0.14.1+cu116 torchaudio==0.13.1 torchtext==0.14.1 torchdata==0.5.1 --extra-index-url https://download.pytorch.org/whl/cu116 -U
# !git clone https://huggingface.co/camenduru/Wav2Lip
# !pip install gradio yt_dlp ffmpeg-python librosa==0.8.0
# %cd Wav2Lip

# %%
# !wget https://huggingface.co/spaces/camenduru/one-shot-talking-face/resolve/main/examples/audio.wav -O /content/audio.wav
# Out:
# --2023-10-19 15:06:51--  https://huggingface.co/spaces/camenduru/one-shot-talking-face/resolve/main/examples/audio.wav
# Resolving huggingface.co (huggingface.co)... 18.239.50.49, 18.239.50.103, 18.239.50.16, ...
# Connecting to huggingface.co (huggingface.co)|18.239.50.49|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: /spaces/camenduru-com/one-shot-talking-face/resolve/main/examples/audio.wav [following]
# --2023-10-19 15:06:51--  https://huggingface.co/spaces/camenduru-com/one-shot-talking-face/resolve/main/examples/audio.wav
# Reusing existing connection to huggingface.co:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 608334 (594K) [audio/wave]
# Saving to: ‘/content/audio.wav’
#
# /content/audio.wav  100%[===================>] 594.08K  --.-KB/s    in 0.02s
#
# 2023-10-19 15:06:51 (26.8 MB/s) - ‘/content/audio.wav’ saved [608334/608334]

# %%
# !python inference.py --checkpoint_path checkpoints/wav2lip_gan.pth --face "/content/img1.png" --audio "/content/sample-0.mp3"
# Out:
# Using cpu for inference.
# Number of frames available for inference: 1
# Extracting raw audio...
# ffmpeg version 4.4.2-0ubuntu0.22.04.1 Copyright (c) 2000-2021 the FFmpeg developers
#   built with gcc 11 (Ubuntu 11.2.0-19ubuntu1)
# ...

# %%
from IPython.display import HTML
from base64 import b64encode
mp4 = open('/content/Wav2Lip/results/result_voice.mp4','rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML(f"""
<video width="50%" height="50%" controls>
      <source src="{data_url}" type="video/mp4">
</video>""")
# Out:
# <video width="50%" height="50%" controls>
#       <source src="data:video/mp4;base64,..." type="video/mp4">
# </video>
